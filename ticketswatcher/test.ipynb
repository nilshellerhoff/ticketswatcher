# %%
from shops import brticket, mphil

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mphil.getConcerts()
# Out:
# [{'provider': 'mphil',
#   'title': 'Dvořák',
#   'datestr': 'Donnerstag, 08.09.2022, 20 Uhr',
#   'datetime': '2022-09-08T20:00:00',
#   'ticketID': None,
#   'image': '/fileadmin/_processed_/e/3/csm_Chung_Myung-Whun_credit_Jean-Francois_Leclercq_600x600_f64ebabe4e.jpg',
#   'url': '/konzerte-karten/kalender/konzerte/dvorak-2022-09-08-1914',
#   'ticket_url': None},
#  {'provider': 'mphil',
#   'title': 'Schumann  Bruckner',
#   'datestr': 'Freitag, 09.09.2022, 20 Uhr',
#   'datetime': '2022-09-09T20:00:00',
#   'ticketID': None,
#   'image': '/fileadmin/_processed_/e/3/csm_Chung_Myung-Whun_credit_Jean-Francois_Leclercq_600x600_f64ebabe4e.jpg',
#   'url': '/konzerte-karten/kalender/konzerte/schumann-bruckner-2022-09-09-1915',
#   'ticket_url': None},
#  {'provider': 'mphil',
#   'title': 'Schumann  Dvořák',
#   'datestr': 'Samstag, 10.09.2022, 20 Uhr',
#   'datetime': '2022-09-10T20:00:00',
#   'ticketID': None,
# ...

# %%
import pytz
import datetime

date = datetime.datetime(2022, 8, 12, 12, 0, 0)
print(date.astimezone(pytz.timezone('UTC')).isoformat())
print(date.dst())
# Out:
# 2022-08-12T10:00:00+00:00
# None

# %%
pytz.all_timezones
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...
